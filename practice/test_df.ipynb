# %%
# importing libraries
import pandas as pd

# %%
# importing dataset
data = pd.read_csv("/home/cimcon/Desktop/Cimcon/Water Data for SQL query/data.csv")

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data.head()
# Out:
#                  DATE-TIME TW St TW Ol St  TW L_R By Act Fault St  \
# 0  2024-04-01 04:05:13.000   Off   Normal  Remote           Fault
# 1  2024-04-01 04:06:00.000   Off   Normal  Remote           Fault
# 2  2024-04-01 04:07:00.000   Off   Normal  Remote           Fault
# 3  2024-04-01 04:08:00.000   Off   Normal  Remote           Fault
# 4  2024-04-01 04:09:01.000   Off   Normal  Remote           Fault
#
#   By Act Opn St By Act Close St Main Act Fault St Main Act Open St  \
# 0     No - data           Close             Fault             Open
# 1     No - data           Close             Fault             Open
# 2     No - data           Close             Fault             Open
# 3     No - data           Close             Fault             Open
# 4     No - data           Close             Fault             Open
#
#   Mani Act Close St  ... Current DC Voltgae Output DC Voltage TW Rh  \
# 0         No - data  ...     0.0        0.0                 0   0.0
# ...

# %%
data['Total Flow'].mean()
# Out:
# 64.88826767960981
